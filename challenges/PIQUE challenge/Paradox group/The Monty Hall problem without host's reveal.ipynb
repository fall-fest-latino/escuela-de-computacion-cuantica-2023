# %%
# Import the neede libraries
import qiskit
from qiskit import IBMQ
from qiskit import QuantumRegister, ClassicalRegister
from qiskit import transpile
from qiskit import QuantumCircuit, execute, Aer
from qiskit.tools.visualization import plot_histogram
from math import pi as pi
import math
import random

# %%
# Load the IBM Quantum Account

MY_API_TOKEN = 'ddc5e3b0b256e5be3237daa8ba467c942e5277418d7f926a73ba99ad513a7b2e70ec780291ebcc096d2a64ff11209fd21ff462378a69a8f38ffc6b344c0ef968' 
IBMQ.save_account(MY_API_TOKEN, overwrite=True)
account = IBMQ.load_account()
print('Credentials loaded')
# Out:
# Credentials loaded

# %%
# Get the provider and the backend
provider = IBMQ.get_provider(group='open')
backend = Aer.get_backend('qasm_simulator')

# %% [markdown]
# # The Monty Hall problem without host's reveal
# $\textit{by 'Paradox' hackaton group}$
#
# The Monty Hall problem is a well-known probability puzzle named after the host of the American television game show "Let's Make a Deal", Monty Hall. The problem goes as follows:
#
# - You are a contestant on a game show. There are three doors, behind one of which is a car, and behind the other two are goats. You choose a door, say Door 1.
# - The host, who knows what's behind each door, opens another door, say Door 3, which has a goat. He then asks you if you want to stick with your initial choice (Door 1) or switch to the remaining unopened door (Door 2).
# - The question is: Should you switch, stick with your initial choice, or does it not matter?
#
# The counter-intuitive solution is that you should always switch. If you stick with your initial choice, your probability of winning the car is $1/3$. However, if you switch, your probability of winning increases to $2/3$.
#
# Now, let's move on to the quantum world. Quantum computing allows us to create **superpositions of states**, which can be used to simulate the Monty Hall problem in a unique way.

# %% [markdown]
# ## Three-Qubit W-States on a Quantum Computer
#
# We can represent the three doors as a three-qubit system. The car and the goats can be represented as different states of the qubits. We can then use a $W \text{state}$ quantum circuit <a href="https://demonstrations.wolfram.com/ThreeQubitWStatesOnAQuantumComputer/">[1]</a> to create a superposition of these states. The W state is a specific quantum state of a multi-qubit system that is an equal superposition of the states where exactly one qubit is in the state $|1⟩$ and the rest are in the state $|0⟩$.

# %%
# W states quantum circuit
from qiskit import QuantumCircuit, QuantumRegister, ClassicalRegister
from qiskit.visualization import plot_histogram, circuit_drawer
import numpy as np
from qiskit.quantum_info import Statevector

# Create a quantum circuit with 3 qubits and 3 classical bits
d = QuantumRegister(3,'door')           # Initialization of a 3 qubit quantum register d
c = ClassicalRegister(3, 'c')           # Initialization of a 3 bit classical register c
qc = QuantumCircuit(d,c)                # Initialization of a Quantum circuit composed of d and c

# Initialize the state of the qubits to the W states
theta = 2 * math.acos(1 / math.sqrt(3)) # angle necessary for the Ry gate.

# W-States circuit
qc.barrier()                            # A barrier to identify the start of the circquit
qc.ry(theta,d[0])                       # Rotation Y gate on quibit 0
qc.ch(d[0],d[1])                        # Controlled Hadamard Gate using qubit 0 as control and qubit 1 as target
qc.cx(d[1],d[2])                        # Controlled X gate on qubit 2 using qubit 1 as control
qc.cx(d[0],d[1])                        # Controlled X gate on qubit 1 using qubit 0 as control
qc.x(d[0])                              # X gate on qubit 1
qc.barrier()                            # A barrier to identify the end of the circquit

# Measurement of the qubits
qc.measure(d,c)                         # Measurement of the quantum register on the classical register

# Plot of the circuit
# %matplotlib inline                      
qc.draw(output="mpl")

# %%
shots_n=1024*10
job = execute(qc, backend, shots=shots_n)
result = job.result()
counts = result.get_counts(qc)
print(counts)
plot_histogram(counts, title="W-states Measurement")
# Out:
# {'010': 3425, '001': 3481, '100': 3334}

# %% [markdown]
# In this histogram we can see what would happen if the contestant in the Monty Hall problem could only choose one of the doors and was not given a chance to change his mind. He will find the goats $|0\rangle$ two thirds of the time, and will find the car $|1\rangle$ only in one third of the time.

# %% [markdown]
# # The Monty Hall Problem With Host's Reveal
#
# Now that we have a way to reproduce the case where the host does not reveal one of the unchosen doors or give you a chance to change your mind, let's try to reproduce what happens when the host reveals one of the goats.
#
# Here's how we can proceed:
# - Contestant Choice: Initialize the qubit of the contestant to the state $\sqrt{\frac{2}{3}}|0\rangle+\frac{1}{\sqrt{3}}|1\rangle$
# - Host's Reveal: Apply a quantum gate to simulate the host revealing a goat behind one of the unchosen doors.
# - Contestant's Decision: Finally, measure the state of the system to simulate the contestant's final choice.

# %% [markdown]
# ## Initialization
# We start by initializing three qubits in the $|0\rangle$ state, representing the three doors. The car is represented by the state $|1\rangle$ and the goats by the state $|0\rangle$.

# %%
from qiskit import QuantumCircuit, QuantumRegister, execute, Aer
import numpy as np

# Create a quantum circuit with 3 qubits
q = QuantumRegister(3,'door')
c = ClassicalRegister(3, 'open')
qc = QuantumCircuit(q,c)

# %% [markdown]
# ## Contestant Choice:
# The contestant chooses a door, in this example, the door 0. This can be represented by initializing the first door to the state $\sqrt{\frac{2}{3}}|0\rangle+\frac{1}{\sqrt{3}}|1\rangle$

# %%
# We prepare the state of the first door to the superposition state 
# where it has 1/3 chance of wining choosing the door 0.

## init_state = [math.sqrt(2/3), math.sqrt(1/3)]
## qc.initialize(init_state, 0)

theta = 2 * math.acos(1 / math.sqrt(3)) # angle necessary for the Ry gate.

# W-States circuit
qc.barrier()                            # A barrier to identify the start of the circquit
qc.ry(theta,d[0])                       # Rotation Y gate on quibit 0
qc.x(q[0])

# %matplotlib inline
qc.draw(output="mpl")

# %% [markdown]
# # Host's Reveal:
#
# The host, who knows what's behind each door, opens one of the other two doors to reveal a goat in state $|0\rangle$. This can be represented by applying a $\text{CNOT}$ gate with the first qubit as control and the revealed door as the target followed by a $\text{NOT}$ gate. This ensures that if the first qubit (the contestant's choice) is in state $|1\rangle$ (car), then the other ones will be in to $|0\rangle$ (goat), and if the first qubit is in state $|0\rangle$, one of the others will be in the state $|1\rangle$,simulating the host reveal.

# %%
revealed = random.randint(1,2)
print(f"The revealed door is door {revealed}")
qc.barrier()

# Apply a not CNOT gate followed by a NOT gate to the revealed door
for i in range(1,3):
    if i == revealed:
        qc.cx(q[0],q[i])
        qc.barrier()
        qc.x(q[i],label='X\n Revealed goat')
        
    # Apply a cnot gate using the revealed as control and the non choosen as target
for i in range(1,3):
    if i != revealed:
        qc.x(q[i], label='X\n Closed door')
        qc.barrier()
        # Apply CNOT gates
        qc.cx(q[0],q[i])
        qc.cx(q[i],q[revealed])
        qc.barrier()


# %matplotlib inline
qc.draw(output="mpl")
# Out:
# The revealed door is door 1

# %% [markdown]
# # Contestant's Decision:
#
# The contestant the has the option to stick with their original choice or switch to the other unopened door. This can be represented by measuring the choosen door:

# %%
qc.measure(q,c)


shots_n=1024*2**7
job = execute(qc, backend, shots=shots_n)
result = job.result()
counts = result.get_counts(qc)
print(counts)
plot_histogram(counts, title=f"The host revealed the goat in door {revealed}.")
# Out:
# {'100': 87508, '001': 43564}

# %% [markdown]
# # Generalization to more than 3 doors
#
# The Monty Hall problem can be generalized to scenarios where there are more than three doors, each hiding either a prize or a goat. In these cases, the contestant’s choice and the host’s actions may depend on the number of doors, the number of prizes, and the host’s rules. In this section, we will explore some of these generalizations and their implications for the contestant’s probability of winning.
#
# ## W-States to more than 3 doors
#
# How can we write a state similar to the W states for more than 3 gates? This has been studied mathematically<a href="https://journals.aps.org/pra/pdf/10.1103/PhysRevA.62.062314">[2]</a>.
#
#
#
# ### State $|W\rangle$ in multiqubit systems
#
# The general W-state is defined as
#
# $$
# |W_n\rangle \equiv (1/\sqrt(N))|N-1,1\rangle
# $$
#
# where $|N-1,1\rangle$ denotes the totally simmetric state including $N-1$ zeros and $1$ ones. For example, if $N=4$, we can write
#
# $$
# |W_4\rangle = (1/\sqrt(4)(|0001\rangle+|0010\rangle+|0100\rangle+|1000\rangle)
# $$
#
# This entangled state guarantees that only one car is measured.
#
# Fortunately, it is possible to initialize these states easily using Qiskit's `Statevector`:

# %%
# W_n states quantum circuit
from qiskit import QuantumCircuit, QuantumRegister, ClassicalRegister
from qiskit.visualization import plot_histogram, circuit_drawer
import numpy as np
from qiskit.quantum_info import Statevector
import itertools

# Initialize the circuit: Start by initializing a quantum circuit with N qubits and N classical bits.

N = 4;                                  # Number of doors to be simulated
q = QuantumRegister(N, 'door')          # 
c = ClassicalRegister(N, 'c')           #
qc = QuantumCircuit(q, c)               #

# Create the W state: The W state is a type of entangled state that can be represented 
# as |W> = (|1000> + |0100> + |0010> + |0001>)/2. To create this state, you can use a combination of 
# Hadamard gates and controlled NOT gates.
# First we generate the labels for the states using itertools

states = [''.join(x) for x in itertools.product('10', repeat=N) if x.count('1') == 1 and x.count('0') == N-1]

# Now we initialize the state with Statevector.from_label method

sv  = 1/math.sqrt(N)*Statevector.from_label(states[N-1])
for i in range(N-1):
    sv = sv + 1/math.sqrt(N)*Statevector.from_label(states[i])
qc.initialize(sv.data, list(range(N)))

# Measurement of the qubits

qc.measure(q,c)                         # Measurement of the quantum register on the classical register

# Plot of the circuit
# %matplotlib inline                      
qc.draw(output="mpl")

# %%
shots_n=1024*10
job = execute(qc, backend, shots=shots_n)
result = job.result()
counts = result.get_counts(qc)
print(counts)
plot_histogram(counts, title="W_n-states Measurement")
# Out:
# {'0010': 2553, '0100': 2542, '1000': 2556, '0001': 2589}

# %% [markdown]
# # The Monty Hall Problem With Host's Reveal and more than 3
#
# - Contestant Choice: Initialize the qubit of the contestant to the state $\sqrt{\frac{(N-1)}{N}}|0\rangle+\frac{1}{\sqrt{N}}|1\rangle$
# - Host's Reveal: Apply a quantum gate to simulate the host revealing a goat behind one of the unchosen doors.
# - Contestant's Decision: Finally, measure the state of the system to simulate the contestant's final choice.

# %% [markdown]
# ## Initialization
# We start by initializing $N$ qubits in the $|0\rangle$ state, representing the $N$ doors. The car is represented by the state $|1\rangle$ and the goats by the state $|0\rangle$.

# %%
from qiskit import QuantumCircuit, QuantumRegister, execute, Aer
import numpy as np

N=4
doors = list(range(N))
choosen = [doors.pop(random.randint(0,len(doors)-1))]
revealed = []
for i in range(len(doors)-1):
    revealed.append(doors.pop(random.randint(0,len(doors)-1)))
closed=doors[0]
print(closed,choosen,revealed)

# Create a quantum circuit with N qubits
q = QuantumRegister(N,'door')
c = ClassicalRegister(N, 'open')
qc = QuantumCircuit(q,c)

# We prepare the state of the first door to the superposition state 
# where it has 1/N chance of wining choosing one of t he doors.

init_state = [math.sqrt((N-1)/N), math.sqrt(1/N)]
qc.initialize(init_state, choosen)

# %matplotlib inline
qc.draw(output="mpl")
# Out:
# 1 [3] [0, 2]

# %% [markdown]
# # Host's Reveal:
#
# The host, who knows what's behind each door, opens one of the other two doors to reveal a goat in state $|0\rangle$. This can be represented by applying a $\text{CNOT}$ gate with the first qubit as control and the revealed door as the target followed by a $\text{NOT}$ gate. This ensures that if the first qubit (the contestant's choice) is in state $|1\rangle$ (car), then the other ones will be in to $|0\rangle$ (goat), and if the first qubit is in state $|0\rangle$, one of the others will be in the state $|1\rangle$,simulating the host reveal.

# %%
# Apply a CNOT gate followed to all revealed doors using the choosen door as control
qc.barrier()
for i in range(0,N):
    if i in revealed:
        if i not in choosen:
            qc.cx(q[choosen],q[i])

# Apply a NOT gate to all not choosen gates
qc.barrier()
for i in range(0,N):
    if i not in choosen:
        qc.x(q[i])
        
# Apply a not CNOT gate to the closed doors using the choosen door as control
qc.barrier()
for i in range(0,N):
    if i not in revealed:
        if i not in choosen:
            qc.cx(q[choosen],q[i])

# Apply a not CNOT gate to the revealed doors using a closed door as control
qc.barrier()
for i in range(0,N):
    if i in revealed:
        qc.cx(q[closed],q[i])
        


# %matplotlib inline
qc.draw(output="mpl")

# %%
qc.measure(q,c)


shots_n=1024*2**7
job = execute(qc, backend, shots=shots_n)
result = job.result()
counts = result.get_counts(qc)
print(counts)
plot_histogram(counts, title=f"The host revealed all doors except door {closed} and the contestant initially choosed door {choosen[0]}.")
# Out:
# {'0010': 98326, '1000': 32746}
